# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

# %%
doc_m='https://open-meteo.com/en/docs/cma-api#latitude=31.2222&longitude=121.4581&timezone=America%2FNew_York'

url='https://api.open-meteo.com/v1/forecast?latitude=52.52&longitude=13.41&current=temperature_2m,apparent_temperature&hourly=temperature_2m,apparent_temperature,weather_code'

# %%
weather=requests.get(url)

# %%
wd=weather.json()
wd
# Out:
# {'latitude': 52.52,
#  'longitude': 13.419998,
#  'generationtime_ms': 0.2340078353881836,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 38.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'apparent_temperature': '°C'},
#  'current': {'time': '2024-11-08T21:00',
#   'interval': 900,
#   'temperature_2m': 4.8,
#   'apparent_temperature': 1.1},
#  'hourly_units': {'time': 'iso8601',
#   'temperature_2m': '°C',
#   'apparent_temperature': '°C',
#   'weather_code': 'wmo code'},
#  'hourly': {'time': ['2024-11-08T00:00',
#    '2024-11-08T01:00',
#    '2024-11-08T02:00',
#    '2024-11-08T03:00',
#    '2024-11-08T04:00',
#    '2024-11-08T05:00',
#    '2024-11-08T06:00',
#    '2024-11-08T07:00',
#    '2024-11-08T08:00',
#    '2024-11-08T09:00',
#    '2024-11-08T10:00',
#    '2024-11-08T11:00',
#    '2024-11-08T12:00',
#    '2024-11-08T13:00',
#    '2024-11-08T14:00',
# ...

# %%
print('This is in Shanghai')
# Out:
# This is in Shanghai

# %%
# it only has lattitudes and longitudes

# %%
longitude=wd['longitude']
latitude=wd['latitude']

# %%
print(f'This place is at {latitude} N {longitude} E.')
# Out:
# This place is at 31.1875 N 121.5 E.

# %%
current_t=wd['current']['temperature_2m']
current_f=wd['current']['apparent_temperature']

# %%
difference=round(abs(current_t-current_f),2)
difference
# Out:
# 3.7

# %%
if current_t>current_f:
    print(f'It feels {difference} degrees colder.')
elif current_t<current_t:
    print(f'It feels {difference} degrees warmer.')
else:
    print('It feels exactly the same!')
# Out:
# It feels 3.7 degrees colder.

# %%
airport_url='https://api.open-meteo.com/v1/forecast?latitude=51.4704&longitude=-0.4586&current=temperature_2m,apparent_temperature&forecast_days=3&models=ukmo_seamless'

# %%
airport_weather=requests.get(airport_url)
aw=airport_weather.json()

# %%
aw
# Out:
# {'latitude': 51.463696,
#  'longitude': -0.45089722,
#  'generationtime_ms': 0.028014183044433594,
#  'utc_offset_seconds': 0,
#  'timezone': 'GMT',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 34.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'apparent_temperature': '°C'},
#  'current': {'time': '2024-11-08T21:15',
#   'interval': 900,
#   'temperature_2m': 8.6,
#   'apparent_temperature': 6.4}}

# %%
current_t=aw['current']['temperature_2m']

# %%
print(f'Current temperature is {current_t} Celsius.')
# Out:
# Current temperature is 8.6 Celsius.

# %%
three_url='https://api.open-meteo.com/v1/forecast?latitude=51.4704&longitude=-0.4586&current=temperature_2m,apparent_temperature&daily=weather_code,temperature_2m_max,temperature_2m_min&timezone=Europe%2FLondon&forecast_days=3&models=ukmo_seamless'

# %%
three_data=requests.get(three_url)
three=three_data.json()

# %%
three
# Out:
# {'latitude': 51.463696,
#  'longitude': -0.45089722,
#  'generationtime_ms': 0.1779794692993164,
#  'utc_offset_seconds': 0,
#  'timezone': 'Europe/London',
#  'timezone_abbreviation': 'GMT',
#  'elevation': 34.0,
#  'current_units': {'time': 'iso8601',
#   'interval': 'seconds',
#   'temperature_2m': '°C',
#   'apparent_temperature': '°C'},
#  'current': {'time': '2024-11-08T21:30',
#   'interval': 900,
#   'temperature_2m': 8.5,
#   'apparent_temperature': 6.5},
#  'daily_units': {'time': 'iso8601',
#   'weather_code': 'wmo code',
#   'temperature_2m_max': '°C',
#   'temperature_2m_min': '°C'},
#  'daily': {'time': ['2024-11-08', '2024-11-09', '2024-11-10'],
#   'weather_code': [3, 3, 3],
#   'temperature_2m_max': [10.2, 10.6, 13.9],
#   'temperature_2m_min': [8.1, 7.2, 10.6]}}

# %%
three['daily']['time']
# Out:
# ['2024-11-08', '2024-11-09', '2024-11-10']

# %%
maxi={}
date=three['daily']['time']
max_temp=three['daily']['temperature_2m_max']

# %%
n=0
t={}
for day in date:
    t[max_temp[n]]=day
    n=n+1
t
# Out:
# {10.2: '2024-11-08', 10.6: '2024-11-09', 13.9: '2024-11-10'}

# %%
m=max(t.keys())
d=t[m]

# %%
print(f'{d} has the highest max temperature at {m} celsius degrees')
# Out:
# 2024-11-10 has the highest max temperature at 13.9 celsius degrees

# %%
#  I prefer this api because the website has python code which I can read to understand what they have
